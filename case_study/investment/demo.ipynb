# %%
import numpy as np
import pandas as pd
import plotly

import matplotlib.pyplot as plt
from model import InvestmentSimulation

# %%
num_people = 100
interest_rate = 0.05
scaling_factor = 1
iteration_time = 100

simulation = InvestmentSimulation(num_people, interest_rate, scaling_factor, iteration_time)
simulation.simulate_society()
simulation.plot_wealth_distribution()

# %%
#simulation.investment_ratio
#plot investment_ratio
plt.plot(simulation.investment_ratio)

# %%
# plot the normal distribution interest return
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

mean = 0.5
deviation = 0.2
scaling_factor = 1

x = np.linspace(0, 1, 100)
y = stats.norm.pdf(x, mean, deviation)
plt.plot(x, y)
plt.show()

# %%
np.random.normal(0.2, 0.1, 10)
# Out:
# array([0.12298044, 0.32894804, 0.06070987, 0.1284094 , 0.14763442,
#        0.12011383, 0.15076387, 0.193637  , 0.07720524, 0.20258629])
